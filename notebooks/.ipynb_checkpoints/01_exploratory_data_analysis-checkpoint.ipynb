# %%
import numpy as np

from src.data.preprocess import generate_valid_tickers, generate_model_inputs
from src.inference.inference import model_inference
from src.training.train import train_model
from src.utils.backtest import backtest, optimise_sharpe
from src.utils.risk import full_risk_report

# %reload_ext autoreload
# %autoreload 2

# %%
valid_tickers = generate_valid_tickers(start_date='2010-12-01',
                                       end_date='2025-12-01')

X, y, stock_ids, regime_X, full_df = generate_model_inputs(tickers=valid_tickers,
                                                           train_start='2010-12-01',
                                                           train_end='2020-12-01',
                                                           hold_days=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       1 valid_tickers = generate_valid_tickers(start_date='2010-12-01',
#       2                                        end_date='2025-12-01')
# ----> 4 X, y, stock_ids, regime_X, full_df = generate_model_inputs(tickers=valid_tickers,
#       5                                                            train_start='2010-12-01',
#       6                                                            train_end='2020-12-01',
#       7                                                            hold_days=5)
#
# File ~/rowan-env-312/multi-asset-transformer/src/data/preprocess.py:28, in generate_model_inputs(tickers, train_start, train_end, hold_days, n_regimes, seq_len, verbose)
#      18 """
#      19 Load raw market and macro datasets from disk and return them as a
#      20 dictionary of DataFrames.
#    (...)     24 does not perform any validation beyond loading and renaming.
#      25 """
#      26 raw_paths = data_cfg['paths']['raw']
# ---> 28 # Risk-free rate
#      29 rf_path = raw_paths['rf']['rf']
#      30 rf = (pd.read_parquet(rf_path)
#      31         .rename(columns={'Close': 'rf'})
#      32         .set_index('Date'))
#
# File ~/rowan-env-312/lib/python3.12/site-packages/pandas/core/frame.py:10784, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10774     if how == "cross":
#   10775         return merge(
#   10776             self,
#   10777             other,
#    (...)  10782             validate=validate,
#   10783         )
# > 10784     return merge(
#   10785         self,
#   10786         other,
#   10787         left_on=on,
#   10788         how=how,
#   10789         left_index=on is None,
#   10790         right_index=True,
#   10791         suffixes=(lsuffix, rsuffix),
#   10792         sort=sort,
#   10793         validate=validate,
#   10794     )
#   10795 else:
#   10796     if on is not None:
#
# File ~/rowan-env-312/lib/python3.12/site-packages/pandas/core/reshape/merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)    182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~/rowan-env-312/lib/python3.12/site-packages/pandas/core/reshape/merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File ~/rowan-env-312/lib/python3.12/site-packages/pandas/core/reshape/merge.py:840, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     837 left = self.left[:]
#     838 right = self.right[:]
# --> 840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
#     848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#    (...)    855         use_na_proxy=True,
#     856     )
#
# File ~/rowan-env-312/lib/python3.12/site-packages/pandas/core/reshape/merge.py:2721, in _items_overlap_with_suffix(left, right, suffixes)
#    2718 lsuffix, rsuffix = suffixes
#    2720 if not lsuffix and not rsuffix:
# -> 2721     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2723 def renamer(x, suffix: str | None):
#    2724     """
#    2725     Rename the left and right indices.
#    2726
#    (...)   2737     x : renamed column name
#    2738     """
#
# ValueError: columns overlap but no suffix specified: Index(['ftse'], dtype='object')

# %%
for i, t in enumerate((1, 5, 21)):
    valid_tickers = generate_valid_tickers(start_date='2010-12-01',
                                           end_date='2025-12-01')
    
    X, y, stock_ids, regime_X, full_df = generate_model_inputs(tickers=valid_tickers,
                                                               train_start='2010-12-01',
                                                               train_end='2020-12-01',
                                                               hold_days=t)
    print('\n')
    train_model(X, y, stock_ids, regime_X, hold_days=t)

    if i<2:
        print('\nNext iteration:\n')
# Out:
# Load successful:
# ~~~~~~~~~~~~~~~~~~~~~~
# Number of rows: 11680
# Number of features: 28
# Number of stocks: 5
# /Users/rowanwalker/rowan-env-312/lib/python3.12/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# Beginning training for 10 epochs on device "mps"
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Epoch 1: Loss = 0.6951. Time taken = 14.25 s
# Epoch 2: Loss = 0.6946. Time taken = 13.63 s
# Epoch 3: Loss = 0.6941. Time taken = 13.67 s
# Epoch 4: Loss = 0.6937. Time taken = 13.68 s
# Epoch 5: Loss = 0.6942. Time taken = 14.49 s
# Epoch 6: Loss = 0.6937. Time taken = 13.39 s
# Epoch 7: Loss = 0.6940. Time taken = 13.35 s
# Epoch 8: Loss = 0.6928. Time taken = 13.76 s
# Epoch 9: Loss = 0.6940. Time taken = 13.59 s
# Epoch 10: Loss = 0.6930. Time taken = 13.57 s
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Training completed. Model saved: ../results/model/model_1.pth
#
# Next iteration:
#
# Load successful:
# ~~~~~~~~~~~~~~~~~~~~~~
# Number of rows: 11660
# Number of features: 28
# Number of stocks: 5
#
#
# Beginning training for 10 epochs on device "mps"
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /Users/rowanwalker/rowan-env-312/lib/python3.12/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# Epoch 1: Loss = 0.6921. Time taken = 14.01 s
# Epoch 2: Loss = 0.6925. Time taken = 14.05 s
# Epoch 3: Loss = 0.6912. Time taken = 14.58 s
# Epoch 4: Loss = 0.6905. Time taken = 14.74 s
# Epoch 5: Loss = 0.6904. Time taken = 15.04 s
# Epoch 6: Loss = 0.6911. Time taken = 15.31 s
# Epoch 7: Loss = 0.6896. Time taken = 15.49 s
# Epoch 8: Loss = 0.6896. Time taken = 18.58 s
# Epoch 9: Loss = 0.6895. Time taken = 18.54 s
# Epoch 10: Loss = 0.6900. Time taken = 16.79 s
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Training completed. Model saved: ../results/model/model_5.pth
#
# Next iteration:
#
# Load successful:
# ~~~~~~~~~~~~~~~~~~~~~~
# Number of rows: 11580
# Number of features: 28
# Number of stocks: 5
#
#
# Beginning training for 10 epochs on device "mps"
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /Users/rowanwalker/rowan-env-312/lib/python3.12/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       5 X, y, stock_ids, regime_X, full_df = generate_model_inputs(tickers=valid_tickers,
#       6                                                            train_start='2010-12-01',
#       7                                                            train_end='2020-12-01',
#       8                                                            hold_days=t)
#       9 print('\n')
# ---> 10 train_model(X, y, stock_ids, regime_X, hold_days=t)
#      12 if i<2:
#      13     print('\nNext iteration:\n')
#
# File ~/rowan-env-312/multi-asset-transformer/src/training/train.py:146, in train_model(X, y, stock_ids, regime_X, hold_days, batch_size, weight_decay, lr, epochs, device, path, verbose)
#     143     optimizer.step()
#     144     scheduler.step()
# --> 146     total_loss += loss.item()
#     148 end = time.perf_counter()
#     149 if verbose:
#
# KeyboardInterrupt:

# %%
model_inference(valid_tickers, full_df, feature_dim=X.shape[2], hold_days=(1,5,21))

# %%
param_grid ={'long_threshold': np.arange(55, 80, 5)/100,
             'short_threshold': np.arange(25, 50, 5)/100,
             'target_vol': np.arange(10, 30, 5)/100,
             'slippage': 1,
             'commission': 1,
             'take_profit': np.arange(2, 21)/100,
             'stop_loss': -np.arange(2, 11)/100,
             'max_hold_days': np.arange(15, 31),
             'max_drawdown': 0.2,
             'leverage': np.arange(1, 10)}

param_grid_best, sharpe = optimise_sharpe(param_grid,
                                          trials=300,
                                          start_date='2021-01-01',
                                          end_date='2025-11-01')

# %%
param_grid_best, sharpe

# %%
s, b, r = backtest(param_grid_best,
                   start_date='2020-01-01',
                   end_date='2024-11-01')

# %%
full_risk_report(s, b, r)

# %%
from src.data.config import load_data_config
data_cfg=load_data_config('../configs/data.yaml')
test=data_cfg['paths']['raw']['ftse']

# %%
test
# Out:
# PosixPath('/Users/rowanwalker/rowan-env-312/multi-asset-transformer/data/raw/ftse')

# %%
file = 'AAPL.parquet'
path = test / file
path
# Out:
# PosixPath('/Users/rowanwalker/rowan-env-312/multi-asset-transformer/data/raw/ftse/AAPL.parquet')

# %%
from src.data.download import download_ftse
download_ftse()
# Out:
# Downloading III.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading ADM.L ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading AAF.L ...
# Downloading ALW.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading AAL.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading ANTO.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading AHT.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading ABF.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading AZN.L ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading AUTO.L ...
# Downloading AV.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BAB.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BA.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BARC.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BTRW.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BEZ.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BKG.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BP.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BATS.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BT-A.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BNZL.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading BRBY.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading CNA.L ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading CCEP.L ...
# Downloading CCH.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading CPG.L ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading CTEC.L ...
# Downloading CRDA.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading DCC.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading DGE.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading DPLM.L ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading EDV.L ...
# Downloading ENT.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading EZJ.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading EXPN.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading FCIT.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading FRES.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading GAW.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading GLEN.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading GSK.L ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading HLN.L ...
# Downloading HLMA.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading HIK.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading HSX.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading HWDN.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading HSBA.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading ICG.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading IHG.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading IMI.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading IMB.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading INF.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading IAG.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading ITRK.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading JD.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading KGF.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading LAND.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading LGEN.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading LLOY.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading LMP.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading LSEG.L ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading MNG.L ...
# Downloading MKS.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading MRO.L ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading MTLN.L ...
# Downloading MNDI.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading NG.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading NWG.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading NXT.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading PSON.L ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Downloading PSH.L ...
# Downloading PSN.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading PHNX.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading PCT.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading PRU.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading RKT.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading REL.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading RTO.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading RMV.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading RIO.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading RR.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SGE.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SBRY.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SDR.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SMT.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SGRO.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SVT.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SHEL.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SMIN.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SN.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SPX.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading SSE.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading STAN.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading STJ.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading TSCO.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading ULVR.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading UU.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading VOD.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading WEIR.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading WTB.L ...
# [*********************100%***********************]  1 of 1 completed
# Downloading WPP.L ...
# [*********************100%***********************]  1 of 1 completed
