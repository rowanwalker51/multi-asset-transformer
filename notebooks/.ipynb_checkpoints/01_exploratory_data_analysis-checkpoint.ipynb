# %%
import numpy as np

from src.data.preprocess import generate_valid_tickers, generate_model_inputs
from src.models.predict import model_prediction
from src.training.train import train_model
from src.utils.backtest import backtest, optimise_sharpe
from src.utils.risk import full_risk_report

# %reload_ext autoreload
# %autoreload 2

# %%
for i, t in enumerate((1, 5, 21)):
    valid_tickers = generate_valid_tickers(start_date='2010-12-01',
                                           end_date='2025-12-01')
    
    X, y, stock_ids, regime_X, full_df = generate_model_inputs(tickers=valid_tickers,
                                                               train_start='2010-12-01',
                                                               train_end='2020-12-01',
                                                               hold_days=t)
    print('\n')
    train_model(X, y, stock_ids, regime_X, hold_days=t)

    if i<2:
        print('\nNext iteration:\n')
# Out:
# Model is not converging.  Current: -27174.290755164333 is not greater than -27174.290699460795. Delta is -5.570353823713958e-05
# Load successful:
# ~~~~~~~~~~~~~~~~~~~~~~
# Number of rows: 11680
# Number of features: 28
# Number of stocks: 5
#
#
# Beginning training for 5 epochs on device "mps"
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Epoch 1: Loss = 0.7032. Time taken = 8.30 s
# Epoch 2: Loss = 0.6990. Time taken = 7.81 s
# Epoch 3: Loss = 0.6962. Time taken = 7.74 s
# Epoch 4: Loss = 0.6960. Time taken = 7.78 s
# Epoch 5: Loss = 0.6964. Time taken = 7.75 s
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Training completed. Model saved: ../results/model/model_1.pth
#
# Next iteration:
#
# Load successful:
# ~~~~~~~~~~~~~~~~~~~~~~
# Number of rows: 11660
# Number of features: 28
# Number of stocks: 5
#
#
# Beginning training for 5 epochs on device "mps"
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Epoch 1: Loss = 0.7112. Time taken = 8.12 s
# Epoch 2: Loss = 0.6944. Time taken = 8.01 s
# Epoch 3: Loss = 0.6943. Time taken = 7.93 s
# Epoch 4: Loss = 0.6932. Time taken = 7.98 s
# Epoch 5: Loss = 0.6916. Time taken = 7.94 s
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Training completed. Model saved: ../results/model/model_5.pth
#
# Next iteration:
#
# Load successful:
# ~~~~~~~~~~~~~~~~~~~~~~
# Number of rows: 11580
# Number of features: 28
# Number of stocks: 5
#
#
# Beginning training for 5 epochs on device "mps"
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Epoch 1: Loss = 0.6888. Time taken = 8.02 s
# Epoch 2: Loss = 0.6878. Time taken = 7.96 s
# Epoch 3: Loss = 0.6830. Time taken = 7.94 s
# Epoch 4: Loss = 0.6816. Time taken = 7.91 s
# Epoch 5: Loss = 0.6794. Time taken = 7.97 s
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Training completed. Model saved: ../results/model/model_21.pth

# %%
model_prediction(valid_tickers, full_df, feature_dim=X.shape[2], hold_days=(1,5,21))
# Out:
# Predicted dataframe saved: ../data/processed/predicted_df.csv
# Time taken: 7.34 seconds

# %%
param_grid ={'long_threshold': np.arange(55, 80, 5)/100,
             'short_threshold': np.arange(25, 50, 5)/100,
             'target_vol': np.arange(10, 30, 5)/100,
             'slippage': 1,
             'commission': 1,
             'take_profit': np.arange(2, 21)/100,
             'stop_loss': -np.arange(2, 11)/100,
             'max_hold_days': np.arange(15, 31),
             'max_drawdown': 0.2,
             'leverage': np.arange(1, 10)}

param_grid_best, sharpe = optimise_sharpe(param_grid,
                                          trials=300,
                                          start_date='2021-01-01',
                                          end_date='2025-11-01')
# Out:
# Starting optimisation for 300 trials...
#
# Trial 10/300 completed.
# Trial 20/300 completed.
# Trial 30/300 completed.
# Trial 40/300 completed.
# Trial 50/300 completed.
# Trial 60/300 completed.
# Trial 70/300 completed.
# Trial 80/300 completed.
# Trial 90/300 completed.
# Trial 100/300 completed.
# Trial 110/300 completed.
# Trial 120/300 completed.
# Trial 130/300 completed.
# Trial 140/300 completed.
# Trial 150/300 completed.
# Trial 160/300 completed.
# Trial 170/300 completed.
# Trial 180/300 completed.
# Trial 190/300 completed.
# Trial 200/300 completed.
# Trial 210/300 completed.
# Trial 220/300 completed.
# Trial 230/300 completed.
# Trial 240/300 completed.
# Trial 250/300 completed.
# Trial 260/300 completed.
# Trial 270/300 completed.
# Trial 280/300 completed.
# Trial 290/300 completed.
# Trial 300/300 completed.

# %%
param_grid_best, sharpe
# Out:
# ({'long_threshold': 0.55,
#   'short_threshold': 0.3,
#   'target_vol': 0.25,
#   'slippage': 1.0,
#   'commission': 1.0,
#   'take_profit': 0.15,
#   'stop_loss': -0.02,
#   'max_hold_days': 16.0,
#   'max_drawdown': 0.2,
#   'leverage': 2.0},
#  3.5376602951620617)

# %%
s, b, r = backtest(param_grid_best,
                   start_date='2021-01-01',
                   end_date='2025-11-01')
# Out:
# Strategy final equity: 31,228
# Buy-and-hold final equity: 1,472
#
#
# Sharpe Ratio: 3.54
# Alpha (annualised): 0.99%
# Beta: 0.76

# %%
full_risk_report(s, b, r)
# Out:
#                         Strategy Benchmark
# Mean Daily Return          0.31%     0.04%
# Daily Vol                  1.31%     0.80%
# Annualized Vol            20.83%    12.72%
# Sharpe Ratio                3.54      0.47
# Sortino Ratio               6.62      0.59
# Max Drawdown             -10.19%   -13.43%
# Drawdown days                 58       288
# Win Rate                  59.09%    55.00%
# Historical VaR (5%)       -1.61%    -1.22%
# Gaussian VaR (5%)         -1.85%    -1.28%
# Cornish-Fisher VaR (5%)   -1.49%    -1.35%
# CVaR (5%)                 -2.25%    -2.00%
