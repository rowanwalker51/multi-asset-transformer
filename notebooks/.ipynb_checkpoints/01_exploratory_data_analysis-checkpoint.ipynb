# %%
import numpy as np

import sys
sys.path.append("../")

from src.utils import risk, params, backtest
from src.training import train
from src.data import preprocess, download
from src.models import predict

# %reload_ext autoreload
# %autoreload 2
    
NUM_STOCKS = 5
N_REGIMES = 3
           
SEQ_LEN = 128
D_MODEL = 64
N_HEAD = 4
N_LAYERS = 2
N_CLASSES = 2
BATCH_SIZE = 32
LR = 1e-5
EPOCHS = 5
DROPOUT = 0.1
WEIGHT_DECAY = 1e-3

# %%
for t in (1, 5, 21):
    valid_tickers = preprocess.generate_valid_tickers(start_date='2010-12-01',
                                                      end_date='2025-12-01',
                                                      num_stocks=NUM_STOCKS)
    
    X, y, stock_ids, regime_X, full_df = preprocess.generate_model_inputs(tickers=valid_tickers,
                                                                          train_start='2010-12-01',
                                                                          train_end='2020-12-01',
                                                                          seq_len=SEQ_LEN,
                                                                          hold_days=t)
    print('\n')
    train.train_model(X, y, stock_ids, regime_X, hold_days=t)

    print('\nNext iteration:\n')
# Out:
# Load successful:
# ~~~~~~~~~~~~~~~~~~~~~~
# Number of rows: 11680
# Number of features: 28
# Number of stocks: 5
#
#
# Beginning training for 5 epochs on device "mps"
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Epoch 1: Loss = 0.7064. Time taken = 6.38 s
# Epoch 2: Loss = 0.7045. Time taken = 6.16 s
# Epoch 3: Loss = 0.7015. Time taken = 5.90 s
# Epoch 4: Loss = 0.6992. Time taken = 5.88 s
# Epoch 5: Loss = 0.6989. Time taken = 6.21 s
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Training completed. Model saved: ../results/model/model_1.pth
#
# Next iteration:
#
# Load successful:
# ~~~~~~~~~~~~~~~~~~~~~~
# Number of rows: 11660
# Number of features: 28
# Number of stocks: 5
#
#
# Beginning training for 5 epochs on device "mps"
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Epoch 1: Loss = 0.7029. Time taken = 6.11 s
# Epoch 2: Loss = 0.6982. Time taken = 5.90 s
# Epoch 3: Loss = 0.6961. Time taken = 5.80 s
# Epoch 4: Loss = 0.6935. Time taken = 5.84 s
# Epoch 5: Loss = 0.6949. Time taken = 5.84 s
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Training completed. Model saved: ../results/model/model_5.pth
#
# Next iteration:
#
# Load successful:
# ~~~~~~~~~~~~~~~~~~~~~~
# Number of rows: 11580
# Number of features: 28
# Number of stocks: 5
#
#
# Beginning training for 5 epochs on device "mps"
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Epoch 1: Loss = 0.7118. Time taken = 5.93 s
# Epoch 2: Loss = 0.6928. Time taken = 5.73 s
# Epoch 3: Loss = 0.6908. Time taken = 5.85 s
# Epoch 4: Loss = 0.6865. Time taken = 5.76 s
# Epoch 5: Loss = 0.6836. Time taken = 5.80 s
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Training completed. Model saved: ../results/model/model_21.pth
#
# Next iteration:

# %%
predict.model_prediction(valid_tickers, full_df, feature_dim=X.shape[2], hold_days=(1,5,21))
# Out:
# Predicted dataframe saved: ../data/processed/predicted_df.csv
# Time taken: 7.42 seconds

# %%
param_grid ={'long_threshold': np.arange(55, 80, 5)/100,
             'short_threshold': np.arange(25, 50, 5)/100,
             'target_vol': np.arange(10, 30, 5)/100,
             'slippage': 1,
             'commission': 1,
             'take_profit': np.arange(2, 21)/100,
             'stop_loss': -np.arange(2, 11)/100,
             'max_hold_days': np.arange(15, 31),
             'max_drawdown': 0.2,
             'leverage': np.arange(1, 10)}

param_grid_best, sharpe = backtest.optimise_sharpe(param_grid,
                                                   trials=300,
                                                   start_date='2021-01-01',
                                                   end_date='2025-11-01')

# %%
param_grid_best, sharpe

# %%
param_grid ={'long_threshold': 0.55,
             'short_threshold': 0.45,
             'target_vol': 0.2,
             'slippage': 1,
             'commission': 1,
             'take_profit': 0.1,
             'stop_loss': -0.02,
             'max_hold_days': 30,
             'max_drawdown': 0.2,
             'leverage': 7}

s, b, r = backtest.backtest(param_grid_best,
                            start_date='2021-01-01',
                            end_date='2025-11-01')

# %%
risk.full_risk_report(s, b, r)
